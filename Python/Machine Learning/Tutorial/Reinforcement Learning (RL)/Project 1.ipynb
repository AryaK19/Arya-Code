# %%
# Image Based learning
import gym
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_atari_env

import os
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Image Based learning
# ----> 2 import gym
#       3 from stable_baselines3 import A2C
#       4 from stable_baselines3.common.vec_env import VecFrameStack
#
# File c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\__init__.py:15
#       7 from gym.core import (
#       8     Env,
#       9     Wrapper,
#    (...)
#      12     RewardWrapper,
#      13 )
#      14 from gym.spaces import Space
# ---> 15 from gym.envs import make, spec, register
#      16 from gym import logger
#      17 from gym import vector
#
# File c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\envs\__init__.py:1
# ----> 1 from gym.envs.registration import load_env_plugins as _load_env_plugins
#       2 from gym.envs.registration import make, register, registry, spec
#       4 # Hook to load plugins from entry points
#
# File c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\envs\registration.py:24
#      10 from typing import (
#      11     Callable,
#      12     Dict,
#    (...)
#      19     overload,
#      20 )
#      22 import numpy as np
# ---> 24 from gym.wrappers import (
#      25     AutoResetWrapper,
#      26     HumanRendering,
#      27     OrderEnforcing,
#      28     RenderCollection,
#      29     TimeLimit,
#      30 )
#      31 from gym.wrappers.compatibility import EnvCompatibility
#      32 from gym.wrappers.env_checker import PassiveEnvChecker
#
# File c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\__init__.py:11
#       9 from gym.wrappers.gray_scale_observation import GrayScaleObservation
#      10 from gym.wrappers.human_rendering import HumanRendering
# ---> 11 from gym.wrappers.normalize import NormalizeObservation, NormalizeReward
#      12 from gym.wrappers.order_enforcing import OrderEnforcing
#      13 from gym.wrappers.record_episode_statistics import RecordEpisodeStatistics
#
# File c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gym\wrappers\normalize.py:49
#      44     new_count = tot_count
#      46     return new_mean, new_var, new_count
# ---> 49 class NormalizeObservation(gym.core.Wrapper):
#      50     """This wrapper will normalize observations s.t. each coordinate is centered with unit variance.
#      51
#      52     Note:
#      53         The normalization depends on past trajectories and observations will not be normalized correctly if the wrapper was
#      54         newly instantiated or the policy was changed recently.
#      55     """
#      57     def __init__(self, env: gym.Env, epsilon: float = 1e-8):
#
# AttributeError: partially initialized module 'gym' has no attribute 'core' (most likely due to a circular import)

# %%
# !python -m atari_py.import_roms .\ROMS\ROMS
# Out:
# c:\Users\arya2\AppData\Local\Programs\Python\Python311\python.exe: Error while finding module specification for 'atari_py.import_roms' (ModuleNotFoundError: No module named 'atari_py')

# %%
environment_name = 'Breakout-v0'
env = gym.make(environment_name)
env.reset()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 environment_name = 'Breakout-v0'
# ----> 2 env = gym.make(environment_name)
#       3 env.reset()
#
# NameError: name 'gym' is not defined

# %%
env.action_space
# Out:
# Discrete(4)

# %%
env.observation_space
# Out:
# Box(0, 255, (210, 160, 3), uint8)

# %%
env = gym.make(environment_name,render_mode="human")
episodes = 1
for episode in range(1,episodes+1):
    obs = env.reset()
    done = False
    score = 0
    
    while not done:
        env.render()
        action = env.action_space.sample()
        obs,reward,done,truncated,info = env.step(action)
        score += reward
    print(f"Episode:({episode}) Score:({score})")
# env.close()
# Out:
# Episode:(1) Score:(0.0)

# %%
env.close()

# %%
env = make_atari_env(environment_name,n_envs=4,seed=0)
env = VecFrameStack(env,n_stack=4)
# Out:
# c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:523: DeprecationWarning: WARN: The environment Breakout-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(

# %%
log_path = os.path.join('Training','Logs')
model = A2C('CnnPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Logging to Training\Logs\A2C_1
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 261      |
# |    ep_rew_mean        | 1.51     |
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 100      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.235   |
# |    explained_variance | 0.0264   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0116   |
# |    value_loss         | 0.242    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 255      |
# |    ep_rew_mean        | 1.29     |
# | time/                 |          |
# |    fps                | 125      |
# |    iterations         | 200      |
# |    time_elapsed       | 31       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.315    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | 0.469    |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 254      |
# |    ep_rew_mean        | 1.2      |
# | time/                 |          |
# |    fps                | 147      |
# |    iterations         | 300      |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.1      |
# |    value_loss         | 0.0496   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 268      |
# |    ep_rew_mean        | 1.36     |
# | time/                 |          |
# |    fps                | 161      |
# |    iterations         | 400      |
# |    time_elapsed       | 49       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0.862    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.36    |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 281      |
# |    ep_rew_mean        | 1.63     |
# | time/                 |          |
# |    fps                | 172      |
# |    iterations         | 500      |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0.31     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 0.271    |
# |    value_loss         | 0.246    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 292      |
# |    ep_rew_mean        | 1.82     |
# | time/                 |          |
# |    fps                | 176      |
# |    iterations         | 600      |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | 0.735    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.00496 |
# |    value_loss         | 0.0608   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 295      |
# |    ep_rew_mean        | 1.85     |
# | time/                 |          |
# |    fps                | 180      |
# |    iterations         | 700      |
# |    time_elapsed       | 77       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0.374    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.254   |
# |    value_loss         | 0.0392   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 307      |
# |    ep_rew_mean        | 2.16     |
# | time/                 |          |
# |    fps                | 185      |
# |    iterations         | 800      |
# |    time_elapsed       | 86       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -0.828   |
# |    explained_variance | 0.511    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -0.0397  |
# |    value_loss         | 0.192    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 321      |
# |    ep_rew_mean        | 2.46     |
# | time/                 |          |
# |    fps                | 189      |
# |    iterations         | 900      |
# |    time_elapsed       | 94       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | 0.722    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0198   |
# |    value_loss         | 0.0674   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 347      |
# |    ep_rew_mean        | 3.01     |
# | time/                 |          |
# |    fps                | 193      |
# |    iterations         | 1000     |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.91    |
# |    explained_variance | 0.909    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.242   |
# |    value_loss         | 0.22     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 372      |
# |    ep_rew_mean        | 3.59     |
# | time/                 |          |
# |    fps                | 196      |
# |    iterations         | 1100     |
# |    time_elapsed       | 111      |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.538   |
# |    explained_variance | 0.397    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.0455  |
# |    value_loss         | 0.0841   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 399      |
# |    ep_rew_mean        | 4.18     |
# | time/                 |          |
# |    fps                | 198      |
# |    iterations         | 1200     |
# |    time_elapsed       | 120      |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.882   |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0711  |
# |    value_loss         | 0.05     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 428      |
# |    ep_rew_mean        | 4.81     |
# | time/                 |          |
# |    fps                | 200      |
# |    iterations         | 1300     |
# |    time_elapsed       | 129      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.477   |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.00404  |
# |    value_loss         | 0.0191   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 449      |
# |    ep_rew_mean        | 5.3      |
# | time/                 |          |
# |    fps                | 202      |
# |    iterations         | 1400     |
# |    time_elapsed       | 138      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.532   |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.00183  |
# |    value_loss         | 0.0466   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 458      |
# |    ep_rew_mean        | 5.49     |
# | time/                 |          |
# |    fps                | 204      |
# |    iterations         | 1500     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -0.586   |
# |    explained_variance | 0.962    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.0445   |
# |    value_loss         | 0.022    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 457      |
# |    ep_rew_mean        | 5.42     |
# | time/                 |          |
# |    fps                | 204      |
# |    iterations         | 1600     |
# |    time_elapsed       | 156      |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.159   |
# |    explained_variance | 0.79     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | 0.000136 |
# |    value_loss         | 0.198    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 465      |
# |    ep_rew_mean        | 5.52     |
# | time/                 |          |
# |    fps                | 206      |
# |    iterations         | 1700     |
# |    time_elapsed       | 164      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -0.291   |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.00225 |
# |    value_loss         | 0.033    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 448      |
# |    ep_rew_mean        | 5.12     |
# | time/                 |          |
# |    fps                | 208      |
# |    iterations         | 1800     |
# |    time_elapsed       | 172      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -0.566   |
# |    explained_variance | 0.781    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.00554 |
# |    value_loss         | 0.0799   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 442      |
# |    ep_rew_mean        | 5.01     |
# | time/                 |          |
# |    fps                | 210      |
# |    iterations         | 1900     |
# |    time_elapsed       | 180      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.26    |
# |    explained_variance | 0.982    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.043    |
# |    value_loss         | 0.0409   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 437      |
# |    ep_rew_mean        | 4.95     |
# | time/                 |          |
# |    fps                | 211      |
# |    iterations         | 2000     |
# |    time_elapsed       | 189      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -0.396   |
# |    explained_variance | 0.741    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | -0.0063  |
# |    value_loss         | 0.105    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 442      |
# |    ep_rew_mean        | 5.09     |
# | time/                 |          |
# |    fps                | 213      |
# |    iterations         | 2100     |
# |    time_elapsed       | 196      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -0.485   |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00554 |
# |    value_loss         | 0.0133   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 431      |
# |    ep_rew_mean        | 4.86     |
# | time/                 |          |
# |    fps                | 214      |
# |    iterations         | 2200     |
# |    time_elapsed       | 205      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.368   |
# |    explained_variance | 0.682    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.169    |
# |    value_loss         | 0.273    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 425      |
# |    ep_rew_mean        | 4.78     |
# | time/                 |          |
# |    fps                | 215      |
# |    iterations         | 2300     |
# |    time_elapsed       | 213      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -0.717   |
# |    explained_variance | 0.85     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.156   |
# |    value_loss         | 0.0736   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 443      |
# |    ep_rew_mean        | 5.13     |
# | time/                 |          |
# |    fps                | 217      |
# |    iterations         | 2400     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | 0.59     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.322    |
# |    value_loss         | 0.157    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 433      |
# |    ep_rew_mean        | 4.88     |
# | time/                 |          |
# |    fps                | 219      |
# |    iterations         | 2500     |
# |    time_elapsed       | 227      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -0.559   |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | 0.0208   |
# |    value_loss         | 0.0174   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 439      |
# |    ep_rew_mean        | 4.99     |
# | time/                 |          |
# |    fps                | 221      |
# |    iterations         | 2600     |
# |    time_elapsed       | 234      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -0.443   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0593  |
# |    value_loss         | 0.0243   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 448      |
# |    ep_rew_mean        | 5.22     |
# | time/                 |          |
# |    fps                | 223      |
# |    iterations         | 2700     |
# |    time_elapsed       | 241      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -0.192   |
# |    explained_variance | 0.969    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.0126  |
# |    value_loss         | 0.0345   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 459      |
# |    ep_rew_mean        | 5.49     |
# | time/                 |          |
# |    fps                | 225      |
# |    iterations         | 2800     |
# |    time_elapsed       | 248      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -0.278   |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.00122 |
# |    value_loss         | 0.162    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 454      |
# |    ep_rew_mean        | 5.44     |
# | time/                 |          |
# |    fps                | 228      |
# |    iterations         | 2900     |
# |    time_elapsed       | 253      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -0.372   |
# |    explained_variance | 0.697    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.116    |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 460      |
# |    ep_rew_mean        | 5.6      |
# | time/                 |          |
# |    fps                | 230      |
# |    iterations         | 3000     |
# |    time_elapsed       | 260      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -0.369   |
# |    explained_variance | 0.731    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.11    |
# |    value_loss         | 0.3      |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 462      |
# |    ep_rew_mean        | 5.68     |
# | time/                 |          |
# |    fps                | 229      |
# |    iterations         | 3100     |
# |    time_elapsed       | 269      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -0.348   |
# |    explained_variance | 0.917    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0756  |
# |    value_loss         | 0.0668   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 466      |
# |    ep_rew_mean        | 5.85     |
# | time/                 |          |
# |    fps                | 230      |
# |    iterations         | 3200     |
# |    time_elapsed       | 277      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -0.282   |
# |    explained_variance | 0.908    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.0143  |
# |    value_loss         | 0.0316   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 457      |
# |    ep_rew_mean        | 5.57     |
# | time/                 |          |
# |    fps                | 232      |
# |    iterations         | 3300     |
# |    time_elapsed       | 284      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.455   |
# |    explained_variance | 0.935    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.00263  |
# |    value_loss         | 0.0116   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 458      |
# |    ep_rew_mean        | 5.56     |
# | time/                 |          |
# |    fps                | 233      |
# |    iterations         | 3400     |
# |    time_elapsed       | 291      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -0.292   |
# |    explained_variance | 0.184    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.034   |
# |    value_loss         | 0.124    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 470      |
# |    ep_rew_mean        | 5.77     |
# | time/                 |          |
# |    fps                | 234      |
# |    iterations         | 3500     |
# |    time_elapsed       | 298      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -0.232   |
# |    explained_variance | 0.864    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.0662  |
# |    value_loss         | 0.176    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 479      |
# |    ep_rew_mean        | 5.98     |
# | time/                 |          |
# |    fps                | 235      |
# |    iterations         | 3600     |
# |    time_elapsed       | 305      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -0.274   |
# |    explained_variance | 0.261    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | 0.368    |
# |    value_loss         | 0.297    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 488      |
# |    ep_rew_mean        | 6.08     |
# | time/                 |          |
# |    fps                | 236      |
# |    iterations         | 3700     |
# |    time_elapsed       | 312      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -0.267   |
# |    explained_variance | 0.937    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.00491  |
# |    value_loss         | 0.0272   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.3      |
# | time/                 |          |
# |    fps                | 237      |
# |    iterations         | 3800     |
# |    time_elapsed       | 319      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -0.249   |
# |    explained_variance | 0.187    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0124   |
# |    value_loss         | 0.127    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 500      |
# |    ep_rew_mean        | 6.27     |
# | time/                 |          |
# |    fps                | 238      |
# |    iterations         | 3900     |
# |    time_elapsed       | 326      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -0.148   |
# |    explained_variance | 0.977    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0106  |
# |    value_loss         | 0.0272   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 490      |
# |    ep_rew_mean        | 6.02     |
# | time/                 |          |
# |    fps                | 240      |
# |    iterations         | 4000     |
# |    time_elapsed       | 333      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -0.105   |
# |    explained_variance | 0.889    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.00717 |
# |    value_loss         | 0.0649   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 509      |
# |    ep_rew_mean        | 6.41     |
# | time/                 |          |
# |    fps                | 241      |
# |    iterations         | 4100     |
# |    time_elapsed       | 340      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -0.286   |
# |    explained_variance | -0.693   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.00535 |
# |    value_loss         | 0.983    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 503      |
# |    ep_rew_mean        | 6.38     |
# | time/                 |          |
# |    fps                | 242      |
# |    iterations         | 4200     |
# |    time_elapsed       | 347      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -0.209   |
# |    explained_variance | 0.723    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0124   |
# |    value_loss         | 0.0968   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 501      |
# |    ep_rew_mean        | 6.4      |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 4300     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -0.212   |
# |    explained_variance | 0.978    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0104  |
# |    value_loss         | 0.0213   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 507      |
# |    ep_rew_mean        | 6.53     |
# | time/                 |          |
# |    fps                | 243      |
# |    iterations         | 4400     |
# |    time_elapsed       | 360      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.211   |
# |    explained_variance | 0.943    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.00431 |
# |    value_loss         | 0.0343   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 512      |
# |    ep_rew_mean        | 6.64     |
# | time/                 |          |
# |    fps                | 244      |
# |    iterations         | 4500     |
# |    time_elapsed       | 367      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -0.338   |
# |    explained_variance | 0.881    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.0432  |
# |    value_loss         | 0.0377   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 518      |
# |    ep_rew_mean        | 6.73     |
# | time/                 |          |
# |    fps                | 245      |
# |    iterations         | 4600     |
# |    time_elapsed       | 374      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -0.182   |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.00922 |
# |    value_loss         | 0.0216   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 512      |
# |    ep_rew_mean        | 6.59     |
# | time/                 |          |
# |    fps                | 246      |
# |    iterations         | 4700     |
# |    time_elapsed       | 381      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -0.197   |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0296  |
# |    value_loss         | 0.0493   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 517      |
# |    ep_rew_mean        | 6.66     |
# | time/                 |          |
# |    fps                | 247      |
# |    iterations         | 4800     |
# |    time_elapsed       | 388      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -0.0902  |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0104   |
# |    value_loss         | 0.0838   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 522      |
# |    ep_rew_mean        | 6.72     |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 4900     |
# |    time_elapsed       | 395      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | 0.763    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | -0.0353  |
# |    value_loss         | 0.18     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 523      |
# |    ep_rew_mean        | 6.7      |
# | time/                 |          |
# |    fps                | 248      |
# |    iterations         | 5000     |
# |    time_elapsed       | 402      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -0.357   |
# |    explained_variance | 0.597    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0376  |
# |    value_loss         | 0.123    |
# ------------------------------------

# %%
save_path = os.path.join('Training','Saved Models','Image_A2C_Model')
model.save(save_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 save_path = os.path.join('Training','Saved Models','Image_A2C_Model')
# ----> 2 model.save(save_path)
#
# NameError: name 'model' is not defined

# %%
model = A2C.load(save_path)

# %%
env = make_atari_env('Breakout-v0',n_envs=1,seed=0)
env = VecFrameStack(env,n_stack=4)
env.metadata['render_fps'] = 40
# Out:
# c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\registration.py:523: DeprecationWarning: WARN: The environment Breakout-v0 is out of date. You should consider upgrading to version `v4`.
#   logger.deprecation(

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# c:\Users\arya2\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\utils\passive_env_checker.py:364: UserWarning: WARN: No render fps was declared in the environment (env.metadata['render_fps'] is None or not defined), rendering may occur at inconsistent fps.
#   logger.warn(
# (0.9, 0.7000000000000001)
